# %%
import pandas as pd;
data=pd.read_csv(r"/content/Police.csv")
data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 44914  9/10/2010     19:15           NaN             M          1981.0
# 44915  9/10/2010     19:21           NaN             F          1986.0
# 44916  9/10/2010     19:37           NaN             F          1987.0
# 44917  9/10/2010     19:40           NaN           NaN             NaN
# 44918  9/10/2010     20:26           NaN             M          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# 0            20.0       White                        Speeding   Speeding
# 1            40.0       White                        Speeding   Speeding
# 2            33.0       White                        Speeding   Speeding
# 3            19.0       White                Call for Service      Other
# 4            21.0       White                        Speeding   Speeding
# ...           ...         ...                             ...        ...
# 44914        29.0    Hispanic                        Speeding   Speeding
# 44915        24.0       White                        Speeding   Speeding
# 44916        23.0       White  Equipment/Inspection Violation  Equipment
# 44917         NaN         NaN                             NaN        NaN
# 44918        25.0       White                        Equipmen        NaN
#
#       search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                False         NaN       Citation       False      0-15 Min
# 1                False         NaN       Citation       False      0-15 Min
# 2                False         NaN       Citation       False      0-15 Min
# 3                False         NaN  Arrest Driver        True     16-30 Min
# 4                False         NaN       Citation       False      0-15 Min
# ...                ...         ...            ...         ...           ...
# 44914            False         NaN       Citation       False      0-15 Min
# 44915            False         NaN       Citation       False      0-15 Min
# 44916            False         NaN        Warning       False      0-15 Min
# 44917            False         NaN            NaN         NaN           NaN
# 44918              NaN         NaN            NaN         NaN           NaN
#
#       drugs_related_stop
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 44914              False
# 44915              False
# 44916              False
# 44917              False
# 44918                NaN
#
# [44919 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          44919
# driver_gender          2819
# driver_age_raw         2811
# driver_age             3039
# driver_race            2818
# violation_raw          2818
# violation              2819
# search_conducted          1
# search_type           43118
# stop_outcome           2819
# is_arrested            2819
# stop_duration          2819
# drugs_related_stop        1
# dtype: int64

# %%
data.drop(columns ='country_name',inplace = True)

# %%
data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 44914  9/10/2010     19:15             M          1981.0        29.0
# 44915  9/10/2010     19:21             F          1986.0        24.0
# 44916  9/10/2010     19:37             F          1987.0        23.0
# 44917  9/10/2010     19:40           NaN             NaN         NaN
# 44918  9/10/2010     20:26             M          1985.0        25.0
#
#       driver_race                   violation_raw  violation search_conducted  \
# 0           White                        Speeding   Speeding            False
# 1           White                        Speeding   Speeding            False
# 2           White                        Speeding   Speeding            False
# 3           White                Call for Service      Other            False
# 4           White                        Speeding   Speeding            False
# ...           ...                             ...        ...              ...
# 44914    Hispanic                        Speeding   Speeding            False
# 44915       White                        Speeding   Speeding            False
# 44916       White  Equipment/Inspection Violation  Equipment            False
# 44917         NaN                             NaN        NaN            False
# 44918       White                        Equipmen        NaN              NaN
#
#       search_type   stop_outcome is_arrested stop_duration drugs_related_stop
# 0             NaN       Citation       False      0-15 Min              False
# 1             NaN       Citation       False      0-15 Min              False
# 2             NaN       Citation       False      0-15 Min              False
# 3             NaN  Arrest Driver        True     16-30 Min              False
# 4             NaN       Citation       False      0-15 Min              False
# ...           ...            ...         ...           ...                ...
# 44914         NaN       Citation       False      0-15 Min              False
# 44915         NaN       Citation       False      0-15 Min              False
# 44916         NaN        Warning       False      0-15 Min              False
# 44917         NaN            NaN         NaN           NaN              False
# 44918         NaN            NaN         NaN           NaN                NaN
#
# [44919 rows x 14 columns]

# %%
data[(data['driver_gender'] == 'M')].value_counts()
# Out:
# stop_date   stop_time  driver_gender  driver_age_raw  driver_age  driver_race  violation_raw                   violation            search_conducted  search_type                          stop_outcome      is_arrested  stop_duration  drugs_related_stop
# 3/6/2009    1:40       M              1990.0          19.0        White        Equipment/Inspection Violation  Equipment            True              Incident to Arrest                   Citation          False        30+ Min        False                 2
# 11/27/2005  8:40       M              1984.0          21.0        White        Other Traffic Violation         Moving violation     True              Incident to Arrest                   Arrest Driver     True         0-15 Min       False                 2
# 7/15/2007   18:08      M              1988.0          19.0        White        Other Traffic Violation         Moving violation     True              Probable Cause                       Citation          False        16-30 Min      False                 2
# 10/12/2005  20:30      M              1987.0          18.0        Hispanic     Other Traffic Violation         Moving violation     True              Protective Frisk                     Arrest Driver     True         0-15 Min       False                 2
# 2/21/2006   1:40       M              1985.0          21.0        Black        Other Traffic Violation         Moving violation     True              Incident to Arrest,Probable Cause    Arrest Driver     True         30+ Min        True                  2
#                                                                                                                                                                                                                                                               ..
# 12/31/2005  9:34       M              1970.0          35.0        White        Speeding                        Speeding             True              Incident to Arrest,Protective Frisk  Arrest Driver     True         30+ Min        False                 1
#             2:17       M              1986.0          19.0        White        Call for Service                Other                True              Incident to Arrest                   Arrest Driver     True         30+ Min        False                 1
# 12/30/2009  5:28       M              1988.0          21.0        Hispanic     Registration Violation          Registration/plates  True              Probable Cause,Protective Frisk      Arrest Driver     True         30+ Min        True                  1
#             23:52      M              1983.0          26.0        Black        Other Traffic Violation         Moving violation     True              Incident to Arrest                   Arrest Passenger  True         16-30 Min      False                 1
# 9/9/2009    1:19       M              1956.0          53.0        White        Other Traffic Violation         Moving violation     True              Incident to Arrest                   Arrest Driver     True         30+ Min        False                 1
# Name: count, Length: 1524, dtype: int64

# %%
data[data.violation =='Speeding'].driver_gender.value_counts()
# Out:
# driver_gender
# M    19666
# F     8655
# Name: count, dtype: int64

# %%
data['search_conducted'] == 'True'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44914    False
# 44915    False
# 44916    False
# 44917    False
# 44918    False
# Name: search_conducted, Length: 44919, dtype: bool

# %%
data.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     267
# M    1534
# Name: search_conducted, dtype: object

# %%
data['stop_duration'].value_counts()
# Out:
# stop_duration
# 0-15 Min     31812
# 16-30 Min     8388
# 30+ Min       1900
# Name: count, dtype: int64

# %%
data['stop_duration']= data['stop_duration'].map({'0-15 Min' : 7.5,'16-30 Min' : 24, '30+ Min' : 45})

# %%
data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 44914  9/10/2010     19:15             M          1981.0        29.0
# 44915  9/10/2010     19:21             F          1986.0        24.0
# 44916  9/10/2010     19:37             F          1987.0        23.0
# 44917  9/10/2010     19:40           NaN             NaN         NaN
# 44918  9/10/2010     20:26             M          1985.0        25.0
#
#       driver_race                   violation_raw  violation search_conducted  \
# 0           White                        Speeding   Speeding            False
# 1           White                        Speeding   Speeding            False
# 2           White                        Speeding   Speeding            False
# 3           White                Call for Service      Other            False
# 4           White                        Speeding   Speeding            False
# ...           ...                             ...        ...              ...
# 44914    Hispanic                        Speeding   Speeding            False
# 44915       White                        Speeding   Speeding            False
# 44916       White  Equipment/Inspection Violation  Equipment            False
# 44917         NaN                             NaN        NaN            False
# 44918       White                        Equipmen        NaN              NaN
#
#       search_type   stop_outcome is_arrested  stop_duration drugs_related_stop
# 0             NaN       Citation       False            7.5              False
# 1             NaN       Citation       False            7.5              False
# 2             NaN       Citation       False            7.5              False
# 3             NaN  Arrest Driver        True           24.0              False
# 4             NaN       Citation       False            7.5              False
# ...           ...            ...         ...            ...                ...
# 44914         NaN       Citation       False            7.5              False
# 44915         NaN       Citation       False            7.5              False
# 44916         NaN        Warning       False            7.5              False
# 44917         NaN            NaN         NaN            NaN              False
# 44918         NaN            NaN         NaN            NaN                NaN
#
# [44919 rows x 14 columns]

# %%
data['stop_duration'].mean()
# Out:
# 12.479857482185274

# %%
data.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             3215.0  31.153655  11.212854  16.0  22.0  27.0  38.0
# Moving violation      6626.0  37.360398  13.192950  15.0  26.0  36.0  47.0
# Other                 2244.0  40.363191  12.622136  16.0  30.0  41.0  50.0
# Registration/plates   1539.0  32.233268  10.894555  16.0  23.0  29.0  40.0
# Speeding             28250.0  33.067221  12.484464  15.0  23.0  29.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                82.0
# Registration/plates  72.0
# Speeding             88.0
